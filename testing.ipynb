# %%
import pandas as pd
import os

# os.listdir("2022\ National Household Travel Survey")
os.listdir("2022_National_Household_Travel_Survey")
# Out:
# ['hhv2pub.csv',
#  'Citation.pdf',
#  'tripv2pub.csv',
#  'codebook.pdf',
#  'ldtv2pub.csv',
#  'perv2pub.csv',
#  'vehv2pub.csv']

# %%
hhv2pub = pd.read_csv("2022_National_Household_Travel_Survey/hhv2pub.csv") # 2022_NHTS_Household_V2_Public_Use
trip2pub = pd.read_csv("2022_National_Household_Travel_Survey/tripv2pub.csv") # 2022_NHTS_Trip_V2_Public_Use
ldtv2pub = pd.read_csv("2022_National_Household_Travel_Survey/ldtv2pub.csv") # 2022_NHTS_Light_Duty_Vehicles_V2_Public_Use
perv2pub = pd.read_csv("2022_National_Household_Travel_Survey/perv2pub.csv") # 2022_NHTS_Person_V2_Public_Use
vehv2pub = pd.read_csv("2022_National_Household_Travel_Survey/vehv2pub.csv") # 2022_NHTS_Vehicles_V2_Public_Use

# %%
hhv2pub.columns
# Out:
# Index(['HOUSEID', 'WTHHFIN', 'WTHHFIN5D', 'WTHHFIN2D', 'NUMADLT', 'HOMEOWN',
#        'HOMETYPE', 'RAIL', 'CENSUS_D', 'CENSUS_R', 'HH_HISP', 'DRVRCNT',
#        'CNTTDHH', 'CDIVMSAR', 'FLAG100', 'HHFAMINC', 'HHFAMINC_IMP', 'HH_RACE',
#        'HHSIZE', 'HHVEHCNT', 'HHRELATD', 'LIF_CYC', 'MSACAT', 'MSASIZE',
#        'TRAVDAY', 'URBAN', 'URBANSIZE', 'URBRUR', 'PPT517', 'YOUNGCHILD',
#        'RESP_CNT', 'URBRUR_2010', 'TDAYDATE', 'WRKCOUNT', 'STRATUMID'],
#       dtype='object')

# %%
## HHVEHCNT == Total number of vehicles 
households_with_1_car = hhv2pub[hhv2pub["HHVEHCNT"] == 1]

# %%
## HOMETYPE
# 01=One-family detached
# 02=One-family attached (townhome, condo) 
# 03=Building with 2 or more apartments
household_filter = [1, 2, 3]
filted_households = households_with_1_car[households_with_1_car["HOMETYPE"].isin(household_filter)]

len(filted_households)
# Out:
# 2494

# %%
for row in filted_households.iterrows():
    household_id = row[1]["HOUSEID"]
    if household_id not in vehv2pub["HOUSEID"].values:
        print(f"Household ID {household_id} not found in vehv2pub")

# %%
merged = filted_households.merge(vehv2pub, on="HOUSEID", how="inner")

# %%
merged.columns
# Out:
# Index(['HOUSEID', 'WTHHFIN_x', 'WTHHFIN5D_x', 'WTHHFIN2D_x', 'NUMADLT_x',
#        'HOMEOWN_x', 'HOMETYPE', 'RAIL_x', 'CENSUS_D_x', 'CENSUS_R_x',
#        'HH_HISP_x', 'DRVRCNT_x', 'CNTTDHH', 'CDIVMSAR_x', 'FLAG100',
#        'HHFAMINC_x', 'HHFAMINC_IMP_x', 'HH_RACE_x', 'HHSIZE_x', 'HHVEHCNT_x',
#        'HHRELATD', 'LIF_CYC_x', 'MSACAT_x', 'MSASIZE_x', 'TRAVDAY_x',
#        'URBAN_x', 'URBANSIZE_x', 'URBRUR_x', 'PPT517', 'YOUNGCHILD',
#        'RESP_CNT', 'URBRUR_2010', 'TDAYDATE_x', 'WRKCOUNT_x', 'STRATUMID_x',
#        'VEHID', 'VEHYEAR', 'MAKE', 'HHVEHCNT_y', 'VEHTYPE', 'VEHFUEL',
#        'VEHCOMMERCIAL', 'VEHCOM_RS', 'VEHCOM_DEL', 'VEHCOM_OTH',
#        'COMMERCIALFREQ', 'HHVEHUSETIME_RS', 'HHVEHUSETIME_DEL',
#        'HHVEHUSETIME_OTH', 'VEHOWNED', 'WHOMAIN', 'VEHCASEID', 'ANNMILES',
#        'HYBRID', 'VEHAGE', 'VEHOWNMO', 'NUMADLT_y', 'HOMEOWN_y', 'RAIL_y',
#        'CENSUS_D_y', 'CENSUS_R_y', 'HH_HISP_y', 'DRVRCNT_y', 'CDIVMSAR_y',
#        'HHFAMINC_y', 'HH_RACE_y', 'HHSIZE_y', 'LIF_CYC_y', 'MSACAT_y',
#        'MSASIZE_y', 'TRAVDAY_y', 'URBAN_y', 'URBANSIZE_y', 'URBRUR_y',
#        'TDAYDATE_y', 'WRKCOUNT_y', 'STRATUMID_y', 'WTHHFIN_y', 'WTHHFIN5D_y',
#        'WTHHFIN2D_y', 'HHFAMINC_IMP_y'],
#       dtype='object')

# %%
household_ids = merged["HOUSEID"].to_list()

# %%
len(household_ids)
# Out:
# 2494

# %%
vehicle_ids = merged["VEHCASEID"].nunique()
# Out:
# 2494

# %%
merged["TRAVDAY_x"].value_counts()
# Out:
# TRAVDAY_x
# 2    432
# 1    412
# 3    390
# 5    331
# 6    326
# 4    315
# 7    288
# Name: count, dtype: int64

# %%
merged[["TRAVDAY_x", "TRAVDAY_y"]]
# Out:
#       TRAVDAY_x  TRAVDAY_y
# 0             4          4
# 1             5          5
# 2             2          2
# 3             3          3
# 4             2          2
# ...         ...        ...
# 2489          3          3
# 2490          2          2
# 2491          5          5
# 2492          1          1
# 2493          5          5
#
# [2494 rows x 2 columns]

# %%
trip2pub_filtered = trip2pub[trip2pub['HOUSEID'].isin(household_ids)]
len(trip2pub_filtered)
# Out:
# 6828

# %%
trip2pub_filtered.columns
# Out:
# Index(['HOUSEID', 'PERSONID', 'TRIPID', 'SEQ_TRIPID', 'VEHCASEID', 'FRSTHM',
#        'PARK', 'HHMEMDRV', 'TDWKND', 'TRAVDAY', 'LOOP_TRIP', 'DWELTIME',
#        'PUBTRANS', 'TRIPPURP', 'WHYFROM', 'WHYTRP1S', 'TRVLCMIN', 'STRTTIME',
#        'ENDTIME', 'TRPHHVEH', 'VEHID', 'TRPTRANS', 'NUMONTRP', 'ONTD_P1',
#        'ONTD_P2', 'ONTD_P3', 'ONTD_P4', 'ONTD_P5', 'ONTD_P6', 'ONTD_P7',
#        'ONTD_P8', 'ONTD_P9', 'ONTD_P10', 'NONHHCNT', 'HHACCCNT', 'WHODROVE',
#        'DRVR_FLG', 'PSGR_FLG', 'WHODROVE_IMP', 'PARK2_PAMOUNT',
#        'PARK2_PAYTYPE', 'PARK2', 'WHYTO', 'WALK', 'TRPMILES', 'WTTRDFIN',
#        'WTTRDFIN5D', 'WTTRDFIN2D', 'TDCASEID', 'VMT_MILE', 'GASPRICE',
#        'WHYTRP90', 'NUMADLT', 'HOMEOWN', 'RAIL', 'CENSUS_D', 'CENSUS_R',
#        'HH_HISP', 'DRVRCNT', 'CDIVMSAR', 'HHFAMINC', 'HH_RACE', 'HHSIZE',
#        'HHVEHCNT', 'LIF_CYC', 'MSACAT', 'MSASIZE', 'URBAN', 'URBANSIZE',
#        'URBRUR', 'TDAYDATE', 'WRKCOUNT', 'STRATUMID', 'R_AGE', 'R_SEX',
#        'WORKER', 'DRIVER', 'R_RACE', 'R_HISP', 'PROXY', 'EDUC', 'PRMACT',
#        'R_SEX_IMP', 'VEHTYPE', 'HHFAMINC_IMP'],
#       dtype='object')

# %%
# Example trips for a household with 1 car
# This person left home to go to the dentist, then went to visit a friend, then went home.
# The household vehicle was used for all trips.
trip2pub_filtered[trip2pub_filtered["HOUSEID"] == 9000013899][['WHYFROM', 'WHYTO', 'WHYTRP1S', 'VMT_MILE', 'TRVLCMIN', 'TRPTRANS', 'TRPHHVEH', 'TRIPID', 'TDAYDATE','TRAVDAY', 'STRTTIME', 'ENDTIME', 'VEHCASEID']]
# Out:
#      WHYFROM  WHYTO  WHYTRP1S   VMT_MILE  TRVLCMIN  TRPTRANS  TRPHHVEH
# 313        1     11        30  11.429459        45         3         1  \
# 314       11     17        50  11.617154        45         3         1
# 315       17      1         1   6.484773        20         3         1
#
#      TRIPID  TDAYDATE  TRAVDAY  STRTTIME  ENDTIME     VEHCASEID
# 313       1    202202        4      1100     1145  900001389901
# 314       2    202202        4      1700     1745  900001389901
# 315       3    202202        4      2100     2120  900001389901

# %%
trip2pub_filtered["VEHCASEID"].value_counts()
# Out:
# VEHCASEID
# -1               1205
#  900021755101      25
#  900007370501      21
#  900010570001      18
#  900007553801      16
#                  ...
#  900010641301       1
#  900007195101       1
#  900001580701       1
#  900005228201       1
#  900009725101       1
# Name: count, Length: 1581, dtype: int64

# %%
len(trip2pub_filtered["VEHCASEID"])
# Out:
# 6828

# %%
trip2pub_filtered_used_car = trip2pub_filtered[trip2pub_filtered["TRPHHVEH"] == 1]

# %%
vehicle_ids = merged["VEHCASEID"].to_list()

# %%
## Aggregating trips by vehicle ID
veh_id_results = {}
veh_id_weird_households = []

# Iterate through each household ID
for veh_id in vehicle_ids:
    
    vehicle_trips = trip2pub_filtered_used_car[trip2pub_filtered_used_car["VEHCASEID"] == veh_id] # Get all the trips for this car
    vehicle_trips = vehicle_trips.sort_values(by=["TDAYDATE", "STRTTIME"])  # Sort by date and time of the trips
    vehicle_trips["TRPHHVEH"].to_list()
    
    # Check that all trips are made in the household vehicle
    if not all(vehicle_trips["TRPHHVEH"] == 1): # SHOULD NEVER GET TRIGGERED since we filtered trips to only include the car trips
        print(f"Household ID {household_id} has trips not made in household vehicle")
        continue
    
    if vehicle_trips.empty:
        # This means the household made no trips (with their car at least) during this day
        travel_day = merged[merged["VEHCASEID"] == veh_id]["TRAVDAY_x"].values[0]
        results[veh_id] = {
            "trips": [], # No trips were made
            "household_id": household_id,
            "day": travel_day,
        }
        continue
    
    # Otherwise, we need to find all the times the vehicle left the house and returned

    current_departure = None
    current_day = None
    
    trips = []
    travel_day = merged[merged["VEHCASEID"] == veh_id]["TRAVDAY_x"].values[0]

    for idx, row in vehicle_trips.iterrows():
        whyfrom = row["WHYFROM"]
        whyto = row["WHYTO"]
        trip_start_time = row["STRTTIME"]
        trip_end_time = row["ENDTIME"]
        miles = row["VMT_MILE"]
        duration = row["TRVLCMIN"]
        day = row["TRAVDAY"]
        assert day == travel_day # should be the same day as the household travel day

        # Case 1: One-row round trip
        if whyfrom in [1, 2] and whyto in [1, 2]:
            trips.append((trip_start_time, trip_end_time, miles))
            current_departure = None  # Reset state in case something was set

        # Case 2: Leaving home (start of trip)
        elif whyfrom in [1, 2]:
            current_departure = trip_start_time

        # Case 3: Returning home (end of a trip)
        elif whyto in [1, 2] and current_departure is not None:
            trips.append((current_departure, trip_end_time, miles))
            current_departure = None

        # Case 4: Unexpected state (returning home without leaving)
        elif whyto in [1, 2] and current_departure is None:
            print(f"veh_id {veh_id} arrived home without prior departure — ignoring row")
    
    if current_departure is not None:
        # This means they left home but never returned
        print(f"veh_id {veh_id} left home but never returned")
        veh_id_weird_households.append(household_id)
        continue
    # Add the trips to the results
    veh_id_results[veh_id] = {
        "trips": trips, # No trips were made
        "day": travel_day,
        }

print(f"Total trips found: {len(veh_id_results)}")
print(f"Weird Households: {len(veh_id_weird_households)}")
# Out:
# veh_id 900001301601 arrived home without prior departure — ignoring row
# veh_id 900001304501 arrived home without prior departure — ignoring row
# veh_id 900001316401 arrived home without prior departure — ignoring row
# veh_id 900001316401 arrived home without prior departure — ignoring row
# veh_id 900001354101 arrived home without prior departure — ignoring row
# veh_id 900001354101 left home but never returned
# veh_id 900001370701 arrived home without prior departure — ignoring row
# veh_id 900001384701 arrived home without prior departure — ignoring row
# veh_id 900001408601 left home but never returned
# veh_id 900001415501 arrived home without prior departure — ignoring row
# veh_id 900001415501 arrived home without prior departure — ignoring row
# veh_id 900001445401 arrived home without prior departure — ignoring row
# veh_id 900001466601 arrived home without prior departure — ignoring row
# veh_id 900001466601 arrived home without prior departure — ignoring row
# veh_id 900001499001 arrived home without prior departure — ignoring row
# veh_id 900001528901 arrived home without prior departure — ignoring row
# veh_id 900001528901 arrived home without prior departure — ignoring row
# veh_id 900001557501 arrived home without prior departure — ignoring row
# veh_id 900001558701 left home but never returned
# veh_id 900001614501 arrived home without prior departure — ignoring row
# veh_id 900001726001 arrived home without prior departure — ignoring row
# veh_id 900001761701 left home but never returned
# veh_id 900001787701 arrived home without prior departure — ignoring row
# veh_id 900001841501 arrived home without prior departure — ignoring row
# veh_id 900001847301 arrived home without prior departure — ignoring row
# veh_id 900001868401 arrived home without prior departure — ignoring row
# veh_id 900001909901 arrived home without prior departure — ignoring row
# veh_id 900004550501 arrived home without prior departure — ignoring row
# veh_id 900004557601 arrived home without prior departure — ignoring row
# veh_id 900004570801 arrived home without prior departure — ignoring row
# veh_id 900004632801 arrived home without prior departure — ignoring row
# veh_id 900004656901 arrived home without prior departure — ignoring row
# veh_id 900004670701 arrived home without prior departure — ignoring row
# veh_id 900004670701 arrived home without prior departure — ignoring row
# veh_id 900004675601 arrived home without prior departure — ignoring row
# veh_id 900004684801 left home but never returned
# veh_id 900004702101 arrived home without prior departure — ignoring row
# veh_id 900004702101 arrived home without prior departure — ignoring row
# veh_id 900004709301 arrived home without prior departure — ignoring row
# veh_id 900004740701 left home but never returned
# veh_id 900004741601 arrived home without prior departure — ignoring row
# veh_id 900004741601 arrived home without prior departure — ignoring row
# veh_id 900004751901 arrived home without prior departure — ignoring row
# veh_id 900004752801 arrived home without prior departure — ignoring row
# veh_id 900004773501 arrived home without prior departure — ignoring row
# veh_id 900004797101 left home but never returned
# veh_id 900004803501 arrived home without prior departure — ignoring row
# veh_id 900004846001 arrived home without prior departure — ignoring row
# veh_id 900004852101 left home but never returned
# veh_id 900004862801 arrived home without prior departure — ignoring row
# veh_id 900004862801 arrived home without prior departure — ignoring row
# veh_id 900004872401 arrived home without prior departure — ignoring row
# veh_id 900004872401 arrived home without prior departure — ignoring row
# veh_id 900004892901 arrived home without prior departure — ignoring row
# veh_id 900004892901 arrived home without prior departure — ignoring row
# veh_id 900004904201 arrived home without prior departure — ignoring row
# veh_id 900004911901 arrived home without prior departure — ignoring row
# veh_id 900004918801 arrived home without prior departure — ignoring row
# veh_id 900004918801 left home but never returned
# veh_id 900004953401 arrived home without prior departure — ignoring row
# veh_id 900004959401 arrived home without prior departure — ignoring row
# veh_id 900004961801 arrived home without prior departure — ignoring row
# veh_id 900004979701 left home but never returned
# veh_id 900005020101 arrived home without prior departure — ignoring row
# veh_id 900005020101 arrived home without prior departure — ignoring row
# veh_id 900005020101 arrived home without prior departure — ignoring row
# veh_id 900005021001 arrived home without prior departure — ignoring row
# veh_id 900005131801 arrived home without prior departure — ignoring row
# veh_id 900005137401 arrived home without prior departure — ignoring row
# veh_id 900005145801 arrived home without prior departure — ignoring row
# veh_id 900005158101 arrived home without prior departure — ignoring row
# veh_id 900005167401 arrived home without prior departure — ignoring row
# veh_id 900005221401 arrived home without prior departure — ignoring row
# veh_id 900005228201 left home but never returned
# veh_id 900005241101 arrived home without prior departure — ignoring row
# veh_id 900005245201 arrived home without prior departure — ignoring row
# veh_id 900005245201 left home but never returned
# veh_id 900005265201 arrived home without prior departure — ignoring row
# veh_id 900005265201 arrived home without prior departure — ignoring row
# veh_id 900005265201 arrived home without prior departure — ignoring row
# veh_id 900005267201 arrived home without prior departure — ignoring row
# veh_id 900005281501 arrived home without prior departure — ignoring row
# veh_id 900005282001 arrived home without prior departure — ignoring row
# veh_id 900005290201 arrived home without prior departure — ignoring row
# veh_id 900005294801 arrived home without prior departure — ignoring row
# veh_id 900005294801 left home but never returned
# veh_id 900005390401 left home but never returned
# veh_id 900005415101 arrived home without prior departure — ignoring row
# veh_id 900005415101 arrived home without prior departure — ignoring row
# veh_id 900005419801 arrived home without prior departure — ignoring row
# veh_id 900005433501 arrived home without prior departure — ignoring row
# veh_id 900005467601 arrived home without prior departure — ignoring row
# veh_id 900005485001 arrived home without prior departure — ignoring row
# veh_id 900005490201 arrived home without prior departure — ignoring row
# veh_id 900005501601 arrived home without prior departure — ignoring row
# veh_id 900005504301 arrived home without prior departure — ignoring row
# veh_id 900005539301 arrived home without prior departure — ignoring row
# veh_id 900005540901 arrived home without prior departure — ignoring row
# veh_id 900005540901 arrived home without prior departure — ignoring row
# veh_id 900005540901 arrived home without prior departure — ignoring row
# veh_id 900005544301 arrived home without prior departure — ignoring row
# veh_id 900005564101 arrived home without prior departure — ignoring row
# veh_id 900005576601 arrived home without prior departure — ignoring row
# veh_id 900005598601 arrived home without prior departure — ignoring row
# veh_id 900005637801 left home but never returned
# veh_id 900005639201 arrived home without prior departure — ignoring row
# veh_id 900005641601 arrived home without prior departure — ignoring row
# veh_id 900005647801 left home but never returned
# veh_id 900005675401 arrived home without prior departure — ignoring row
# veh_id 900005675401 arrived home without prior departure — ignoring row
# veh_id 900005682601 arrived home without prior departure — ignoring row
# veh_id 900005683801 left home but never returned
# veh_id 900005696201 arrived home without prior departure — ignoring row
# veh_id 900005706901 arrived home without prior departure — ignoring row
# veh_id 900005707401 left home but never returned
# veh_id 900005711901 arrived home without prior departure — ignoring row
# veh_id 900005730601 arrived home without prior departure — ignoring row
# veh_id 900005745401 arrived home without prior departure — ignoring row
# veh_id 900005751801 arrived home without prior departure — ignoring row
# veh_id 900005767701 arrived home without prior departure — ignoring row
# veh_id 900005773401 arrived home without prior departure — ignoring row
# veh_id 900007182601 arrived home without prior departure — ignoring row
# veh_id 900007195101 left home but never returned
# veh_id 900007255501 left home but never returned
# veh_id 900007291001 arrived home without prior departure — ignoring row
# veh_id 900007291001 arrived home without prior departure — ignoring row
# veh_id 900007314101 left home but never returned
# veh_id 900007328301 arrived home without prior departure — ignoring row
# veh_id 900007334101 arrived home without prior departure — ignoring row
# veh_id 900007355101 arrived home without prior departure — ignoring row
# veh_id 900007355101 arrived home without prior departure — ignoring row
# veh_id 900007355101 left home but never returned
# veh_id 900007365801 arrived home without prior departure — ignoring row
# veh_id 900007370501 arrived home without prior departure — ignoring row
# veh_id 900007370501 arrived home without prior departure — ignoring row
# veh_id 900007370501 arrived home without prior departure — ignoring row
# veh_id 900007370501 arrived home without prior departure — ignoring row
# veh_id 900007414401 arrived home without prior departure — ignoring row
# veh_id 900007448601 left home but never returned
# veh_id 900007483701 arrived home without prior departure — ignoring row
# veh_id 900007498301 arrived home without prior departure — ignoring row
# veh_id 900007503701 arrived home without prior departure — ignoring row
# veh_id 900007511101 arrived home without prior departure — ignoring row
# veh_id 900007517501 arrived home without prior departure — ignoring row
# veh_id 900007521401 arrived home without prior departure — ignoring row
# veh_id 900007523401 left home but never returned
# veh_id 900007553801 arrived home without prior departure — ignoring row
# veh_id 900007578801 arrived home without prior departure — ignoring row
# veh_id 900007600601 arrived home without prior departure — ignoring row
# veh_id 900007600601 left home but never returned
# veh_id 900007607501 arrived home without prior departure — ignoring row
# veh_id 900007616001 arrived home without prior departure — ignoring row
# veh_id 900007616001 arrived home without prior departure — ignoring row
# veh_id 900007630901 arrived home without prior departure — ignoring row
# veh_id 900007630901 arrived home without prior departure — ignoring row
# veh_id 900007638001 arrived home without prior departure — ignoring row
# veh_id 900007644001 left home but never returned
# veh_id 900007646401 arrived home without prior departure — ignoring row
# veh_id 900007650501 arrived home without prior departure — ignoring row
# veh_id 900007672301 arrived home without prior departure — ignoring row
# veh_id 900007672301 arrived home without prior departure — ignoring row
# veh_id 900007672401 arrived home without prior departure — ignoring row
# veh_id 900007679201 arrived home without prior departure — ignoring row
# veh_id 900007680101 arrived home without prior departure — ignoring row
# veh_id 900007680101 left home but never returned
# veh_id 900007682301 arrived home without prior departure — ignoring row
# veh_id 900007689501 arrived home without prior departure — ignoring row
# veh_id 900007713601 left home but never returned
# veh_id 900007716701 arrived home without prior departure — ignoring row
# veh_id 900007725601 left home but never returned
# veh_id 900007740401 arrived home without prior departure — ignoring row
# veh_id 900007744001 arrived home without prior departure — ignoring row
# veh_id 900007768501 arrived home without prior departure — ignoring row
# veh_id 900008655201 left home but never returned
# veh_id 900008676401 left home but never returned
# veh_id 900008697301 left home but never returned
# veh_id 900008704901 left home but never returned
# veh_id 900008735701 arrived home without prior departure — ignoring row
# veh_id 900008747501 arrived home without prior departure — ignoring row
# veh_id 900008747501 arrived home without prior departure — ignoring row
# veh_id 900008747501 arrived home without prior departure — ignoring row
# veh_id 900008761301 arrived home without prior departure — ignoring row
# veh_id 900008768101 arrived home without prior departure — ignoring row
# veh_id 900008770001 left home but never returned
# veh_id 900008774001 arrived home without prior departure — ignoring row
# veh_id 900008802301 arrived home without prior departure — ignoring row
# veh_id 900008806101 arrived home without prior departure — ignoring row
# veh_id 900008807501 arrived home without prior departure — ignoring row
# veh_id 900008822901 arrived home without prior departure — ignoring row
# veh_id 900008831301 arrived home without prior departure — ignoring row
# veh_id 900008834901 arrived home without prior departure — ignoring row
# veh_id 900008834901 arrived home without prior departure — ignoring row
# veh_id 900008840401 arrived home without prior departure — ignoring row
# veh_id 900008871601 arrived home without prior departure — ignoring row
# veh_id 900008882501 arrived home without prior departure — ignoring row
# veh_id 900008917301 arrived home without prior departure — ignoring row
# veh_id 900008917301 arrived home without prior departure — ignoring row
# veh_id 900008917301 arrived home without prior departure — ignoring row
# veh_id 900008917301 arrived home without prior departure — ignoring row
# veh_id 900008936901 left home but never returned
# veh_id 900008967601 arrived home without prior departure — ignoring row
# veh_id 900008967601 left home but never returned
# veh_id 900008972401 left home but never returned
# veh_id 900008990001 arrived home without prior departure — ignoring row
# veh_id 900008992001 arrived home without prior departure — ignoring row
# veh_id 900008992001 arrived home without prior departure — ignoring row
# veh_id 900008992001 arrived home without prior departure — ignoring row
# veh_id 900009579801 arrived home without prior departure — ignoring row
# veh_id 900009583901 arrived home without prior departure — ignoring row
# veh_id 900009583901 arrived home without prior departure — ignoring row
# veh_id 900009591001 arrived home without prior departure — ignoring row
# veh_id 900009600801 arrived home without prior departure — ignoring row
# veh_id 900009600901 arrived home without prior departure — ignoring row
# veh_id 900009607801 arrived home without prior departure — ignoring row
# veh_id 900009609701 left home but never returned
# veh_id 900009617501 left home but never returned
# veh_id 900009619001 left home but never returned
# veh_id 900009627001 arrived home without prior departure — ignoring row
# veh_id 900009632601 arrived home without prior departure — ignoring row
# veh_id 900009645101 left home but never returned
# veh_id 900009721501 arrived home without prior departure — ignoring row
# veh_id 900009721501 arrived home without prior departure — ignoring row
# veh_id 900009724901 left home but never returned
# veh_id 900009725101 left home but never returned
# veh_id 900009725901 left home but never returned
# veh_id 900009795401 arrived home without prior departure — ignoring row
# veh_id 900009795401 arrived home without prior departure — ignoring row
# veh_id 900009841601 left home but never returned
# veh_id 900009851301 arrived home without prior departure — ignoring row
# veh_id 900009874301 left home but never returned
# veh_id 900009885301 arrived home without prior departure — ignoring row
# veh_id 900009902001 arrived home without prior departure — ignoring row
# veh_id 900010455501 arrived home without prior departure — ignoring row
# veh_id 900010466001 arrived home without prior departure — ignoring row
# veh_id 900010469801 arrived home without prior departure — ignoring row
# veh_id 900010489701 arrived home without prior departure — ignoring row
# veh_id 900010489701 arrived home without prior departure — ignoring row
# veh_id 900010499301 left home but never returned
# veh_id 900010544201 arrived home without prior departure — ignoring row
# veh_id 900010570001 arrived home without prior departure — ignoring row
# veh_id 900010570001 arrived home without prior departure — ignoring row
# veh_id 900010570001 arrived home without prior departure — ignoring row
# veh_id 900010570001 arrived home without prior departure — ignoring row
# veh_id 900010576901 arrived home without prior departure — ignoring row
# veh_id 900010611101 arrived home without prior departure — ignoring row
# veh_id 900010629101 arrived home without prior departure — ignoring row
# veh_id 900010641801 arrived home without prior departure — ignoring row
# veh_id 900010650601 arrived home without prior departure — ignoring row
# veh_id 900010652801 arrived home without prior departure — ignoring row
# veh_id 900010659501 arrived home without prior departure — ignoring row
# veh_id 900010751301 arrived home without prior departure — ignoring row
# veh_id 900010766101 left home but never returned
# veh_id 900010790201 arrived home without prior departure — ignoring row
# veh_id 900011363101 left home but never returned
# veh_id 900011365401 arrived home without prior departure — ignoring row
# veh_id 900011365401 arrived home without prior departure — ignoring row
# veh_id 900011369201 arrived home without prior departure — ignoring row
# veh_id 900011376201 left home but never returned
# veh_id 900011396501 left home but never returned
# veh_id 900011442201 arrived home without prior departure — ignoring row
# veh_id 900011458001 left home but never returned
# veh_id 900011468501 arrived home without prior departure — ignoring row
# veh_id 900011468501 left home but never returned
# veh_id 900011490101 arrived home without prior departure — ignoring row
# veh_id 900011494601 arrived home without prior departure — ignoring row
# veh_id 900011495601 left home but never returned
# veh_id 900011497601 arrived home without prior departure — ignoring row
# veh_id 900011497601 arrived home without prior departure — ignoring row
# veh_id 900011497601 arrived home without prior departure — ignoring row
# veh_id 900011519101 arrived home without prior departure — ignoring row
# veh_id 900011519401 left home but never returned
# veh_id 900011533301 arrived home without prior departure — ignoring row
# veh_id 900011541301 arrived home without prior departure — ignoring row
# veh_id 900011541301 left home but never returned
# veh_id 900011568101 arrived home without prior departure — ignoring row
# veh_id 900011572101 arrived home without prior departure — ignoring row
# veh_id 900011588001 left home but never returned
# veh_id 900011640201 arrived home without prior departure — ignoring row
# veh_id 900011678001 arrived home without prior departure — ignoring row
# veh_id 900011683201 arrived home without prior departure — ignoring row
# veh_id 900011683201 arrived home without prior departure — ignoring row
# veh_id 900011703501 arrived home without prior departure — ignoring row
# veh_id 900011707401 left home but never returned
# veh_id 900011715901 arrived home without prior departure — ignoring row
# veh_id 900011733101 arrived home without prior departure — ignoring row
# veh_id 900011734001 arrived home without prior departure — ignoring row
# veh_id 900011734001 left home but never returned
# veh_id 900011742401 left home but never returned
# veh_id 900012494801 arrived home without prior departure — ignoring row
# veh_id 900012498401 arrived home without prior departure — ignoring row
# veh_id 900012498401 arrived home without prior departure — ignoring row
# veh_id 900012525701 arrived home without prior departure — ignoring row
# veh_id 900012529901 left home but never returned
# veh_id 900012587301 arrived home without prior departure — ignoring row
# veh_id 900012587301 arrived home without prior departure — ignoring row
# veh_id 900012591601 arrived home without prior departure — ignoring row
# veh_id 900012591601 arrived home without prior departure — ignoring row
# veh_id 900012591601 arrived home without prior departure — ignoring row
# veh_id 900012614401 arrived home without prior departure — ignoring row
# veh_id 900012645901 left home but never returned
# veh_id 900012679401 arrived home without prior departure — ignoring row
# veh_id 900012691001 arrived home without prior departure — ignoring row
# veh_id 900012703401 arrived home without prior departure — ignoring row
# veh_id 900012720801 arrived home without prior departure — ignoring row
# veh_id 900012739901 arrived home without prior departure — ignoring row
# veh_id 900012739901 arrived home without prior departure — ignoring row
# veh_id 900012752401 arrived home without prior departure — ignoring row
# veh_id 900012767701 arrived home without prior departure — ignoring row
# veh_id 900012767701 arrived home without prior departure — ignoring row
# veh_id 900012767701 left home but never returned
# veh_id 900012812301 arrived home without prior departure — ignoring row
# veh_id 900012819001 arrived home without prior departure — ignoring row
# veh_id 900012819001 arrived home without prior departure — ignoring row
# veh_id 900012823501 arrived home without prior departure — ignoring row
# veh_id 900012823501 arrived home without prior departure — ignoring row
# veh_id 900012823501 arrived home without prior departure — ignoring row
# veh_id 900012836701 arrived home without prior departure — ignoring row
# veh_id 900012838701 left home but never returned
# veh_id 900012858201 arrived home without prior departure — ignoring row
# veh_id 900012858201 left home but never returned
# veh_id 900012861001 arrived home without prior departure — ignoring row
# veh_id 900012865301 arrived home without prior departure — ignoring row
# veh_id 900012880801 arrived home without prior departure — ignoring row
# veh_id 900012880801 arrived home without prior departure — ignoring row
# veh_id 900012899401 left home but never returned
# veh_id 900014513301 left home but never returned
# veh_id 900014525801 arrived home without prior departure — ignoring row
# veh_id 900014525801 arrived home without prior departure — ignoring row
# veh_id 900014530401 arrived home without prior departure — ignoring row
# veh_id 900014535001 left home but never returned
# veh_id 900014535401 arrived home without prior departure — ignoring row
# veh_id 900014537301 arrived home without prior departure — ignoring row
# veh_id 900014537301 left home but never returned
# veh_id 900014568301 arrived home without prior departure — ignoring row
# veh_id 900014646501 left home but never returned
# veh_id 900014646601 arrived home without prior departure — ignoring row
# veh_id 900014646601 arrived home without prior departure — ignoring row
# veh_id 900014646601 arrived home without prior departure — ignoring row
# veh_id 900014657401 arrived home without prior departure — ignoring row
# veh_id 900014667501 arrived home without prior departure — ignoring row
# veh_id 900014670801 arrived home without prior departure — ignoring row
# veh_id 900014748001 arrived home without prior departure — ignoring row
# veh_id 900014755901 arrived home without prior departure — ignoring row
# veh_id 900014759801 arrived home without prior departure — ignoring row
# veh_id 900014759801 arrived home without prior departure — ignoring row
# veh_id 900014774501 left home but never returned
# veh_id 900014786601 arrived home without prior departure — ignoring row
# veh_id 900014788601 arrived home without prior departure — ignoring row
# veh_id 900014812701 left home but never returned
# veh_id 900014836001 arrived home without prior departure — ignoring row
# veh_id 900014853301 arrived home without prior departure — ignoring row
# veh_id 900014886701 arrived home without prior departure — ignoring row
# veh_id 900014887101 arrived home without prior departure — ignoring row
# veh_id 900014904701 arrived home without prior departure — ignoring row
# veh_id 900014927201 arrived home without prior departure — ignoring row
# veh_id 900014928101 left home but never returned
# veh_id 900014939601 left home but never returned
# veh_id 900016214301 left home but never returned
# veh_id 900016223901 arrived home without prior departure — ignoring row
# veh_id 900016228701 arrived home without prior departure — ignoring row
# veh_id 900016235501 left home but never returned
# veh_id 900016249601 arrived home without prior departure — ignoring row
# veh_id 900016249601 left home but never returned
# veh_id 900016294201 arrived home without prior departure — ignoring row
# veh_id 900016296101 arrived home without prior departure — ignoring row
# veh_id 900016325601 left home but never returned
# veh_id 900016337201 left home but never returned
# veh_id 900016402201 arrived home without prior departure — ignoring row
# veh_id 900016416601 arrived home without prior departure — ignoring row
# veh_id 900016416601 left home but never returned
# veh_id 900016423401 left home but never returned
# veh_id 900016437801 arrived home without prior departure — ignoring row
# veh_id 900016463201 arrived home without prior departure — ignoring row
# veh_id 900016467401 arrived home without prior departure — ignoring row
# veh_id 900016490801 arrived home without prior departure — ignoring row
# veh_id 900016500501 arrived home without prior departure — ignoring row
# veh_id 900016500501 left home but never returned
# veh_id 900016504901 arrived home without prior departure — ignoring row
# veh_id 900016513401 arrived home without prior departure — ignoring row
# veh_id 900016528701 arrived home without prior departure — ignoring row
# veh_id 900016535601 arrived home without prior departure — ignoring row
# veh_id 900016535601 arrived home without prior departure — ignoring row
# veh_id 900016535601 arrived home without prior departure — ignoring row
# veh_id 900016603701 left home but never returned
# veh_id 900016631001 arrived home without prior departure — ignoring row
# veh_id 900016635401 arrived home without prior departure — ignoring row
# veh_id 900016652401 arrived home without prior departure — ignoring row
# veh_id 900016663601 arrived home without prior departure — ignoring row
# veh_id 900016663601 left home but never returned
# veh_id 900016675701 arrived home without prior departure — ignoring row
# veh_id 900016699701 arrived home without prior departure — ignoring row
# veh_id 900016744201 arrived home without prior departure — ignoring row
# veh_id 900016746401 arrived home without prior departure — ignoring row
# veh_id 900016746401 left home but never returned
# veh_id 900016748001 arrived home without prior departure — ignoring row
# veh_id 900016759701 arrived home without prior departure — ignoring row
# veh_id 900016760101 arrived home without prior departure — ignoring row
# veh_id 900016762701 arrived home without prior departure — ignoring row
# veh_id 900016763201 arrived home without prior departure — ignoring row
# veh_id 900016804301 arrived home without prior departure — ignoring row
# veh_id 900016820401 arrived home without prior departure — ignoring row
# veh_id 900016820401 arrived home without prior departure — ignoring row
# veh_id 900016826301 arrived home without prior departure — ignoring row
# veh_id 900016826301 left home but never returned
# veh_id 900016862001 arrived home without prior departure — ignoring row
# veh_id 900016866201 left home but never returned
# veh_id 900016883001 arrived home without prior departure — ignoring row
# veh_id 900016883001 arrived home without prior departure — ignoring row
# veh_id 900016905201 arrived home without prior departure — ignoring row
# veh_id 900016950701 arrived home without prior departure — ignoring row
# veh_id 900016950701 arrived home without prior departure — ignoring row
# veh_id 900016970801 arrived home without prior departure — ignoring row
# veh_id 900017008101 arrived home without prior departure — ignoring row
# veh_id 900017010701 arrived home without prior departure — ignoring row
# veh_id 900017040801 arrived home without prior departure — ignoring row
# veh_id 900017040801 left home but never returned
# veh_id 900017055901 arrived home without prior departure — ignoring row
# veh_id 900017055901 arrived home without prior departure — ignoring row
# veh_id 900017061401 left home but never returned
# veh_id 900017062901 arrived home without prior departure — ignoring row
# veh_id 900017074701 arrived home without prior departure — ignoring row
# veh_id 900017074701 arrived home without prior departure — ignoring row
# veh_id 900017128501 left home but never returned
# veh_id 900017153701 arrived home without prior departure — ignoring row
# veh_id 900017154901 arrived home without prior departure — ignoring row
# veh_id 900017156001 arrived home without prior departure — ignoring row
# veh_id 900017185401 arrived home without prior departure — ignoring row
# veh_id 900017209201 arrived home without prior departure — ignoring row
# veh_id 900017235501 left home but never returned
# veh_id 900017240801 arrived home without prior departure — ignoring row
# veh_id 900017243801 arrived home without prior departure — ignoring row
# veh_id 900017246001 arrived home without prior departure — ignoring row
# veh_id 900017250801 arrived home without prior departure — ignoring row
# veh_id 900017273601 left home but never returned
# veh_id 900017282001 arrived home without prior departure — ignoring row
# veh_id 900017282001 arrived home without prior departure — ignoring row
# veh_id 900017284501 arrived home without prior departure — ignoring row
# veh_id 900017285201 arrived home without prior departure — ignoring row
# veh_id 900017287501 arrived home without prior departure — ignoring row
# veh_id 900017287501 left home but never returned
# veh_id 900017302001 arrived home without prior departure — ignoring row
# veh_id 900017343501 arrived home without prior departure — ignoring row
# veh_id 900017345301 arrived home without prior departure — ignoring row
# veh_id 900017349101 arrived home without prior departure — ignoring row
# veh_id 900017349101 arrived home without prior departure — ignoring row
# veh_id 900017376001 arrived home without prior departure — ignoring row
# veh_id 900017406501 arrived home without prior departure — ignoring row
# veh_id 900017447101 arrived home without prior departure — ignoring row
# veh_id 900017465801 arrived home without prior departure — ignoring row
# veh_id 900017478301 arrived home without prior departure — ignoring row
# veh_id 900017493601 arrived home without prior departure — ignoring row
# veh_id 900017498401 left home but never returned
# veh_id 900017499901 left home but never returned
# veh_id 900017519001 arrived home without prior departure — ignoring row
# veh_id 900017519001 arrived home without prior departure — ignoring row
# veh_id 900017519001 arrived home without prior departure — ignoring row
# veh_id 900017522001 arrived home without prior departure — ignoring row
# veh_id 900017525001 arrived home without prior departure — ignoring row
# veh_id 900017525901 arrived home without prior departure — ignoring row
# veh_id 900017526501 left home but never returned
# veh_id 900017550701 arrived home without prior departure — ignoring row
# veh_id 900017559801 arrived home without prior departure — ignoring row
# veh_id 900017567601 arrived home without prior departure — ignoring row
# veh_id 900017573401 left home but never returned
# veh_id 900020865101 arrived home without prior departure — ignoring row
# veh_id 900020908601 arrived home without prior departure — ignoring row
# veh_id 900020908601 arrived home without prior departure — ignoring row
# veh_id 900020908601 arrived home without prior departure — ignoring row
# veh_id 900020924801 arrived home without prior departure — ignoring row
# veh_id 900020931001 arrived home without prior departure — ignoring row
# veh_id 900020954201 arrived home without prior departure — ignoring row
# veh_id 900021006801 arrived home without prior departure — ignoring row
# veh_id 900021006801 arrived home without prior departure — ignoring row
# veh_id 900021006801 arrived home without prior departure — ignoring row
# veh_id 900021006801 arrived home without prior departure — ignoring row
# veh_id 900021008801 arrived home without prior departure — ignoring row
# veh_id 900021008801 arrived home without prior departure — ignoring row
# veh_id 900021008801 arrived home without prior departure — ignoring row
# veh_id 900021008801 arrived home without prior departure — ignoring row
# veh_id 900021008801 arrived home without prior departure — ignoring row
# veh_id 900021008801 arrived home without prior departure — ignoring row
# veh_id 900021019701 left home but never returned
# veh_id 900021025201 left home but never returned
# veh_id 900021026401 arrived home without prior departure — ignoring row
# veh_id 900021042101 left home but never returned
# veh_id 900021045201 left home but never returned
# veh_id 900021057601 arrived home without prior departure — ignoring row
# veh_id 900021061801 left home but never returned
# veh_id 900021069101 arrived home without prior departure — ignoring row
# veh_id 900021070701 left home but never returned
# veh_id 900021074201 arrived home without prior departure — ignoring row
# veh_id 900021095201 arrived home without prior departure — ignoring row
# veh_id 900021099601 arrived home without prior departure — ignoring row
# veh_id 900021108401 arrived home without prior departure — ignoring row
# veh_id 900021117101 left home but never returned
# veh_id 900021142901 arrived home without prior departure — ignoring row
# veh_id 900021143201 arrived home without prior departure — ignoring row
# veh_id 900021149801 arrived home without prior departure — ignoring row
# veh_id 900021160401 arrived home without prior departure — ignoring row
# veh_id 900021160401 arrived home without prior departure — ignoring row
# veh_id 900021160401 left home but never returned
# veh_id 900021186101 arrived home without prior departure — ignoring row
# veh_id 900021192501 arrived home without prior departure — ignoring row
# veh_id 900021204401 arrived home without prior departure — ignoring row
# veh_id 900021215001 arrived home without prior departure — ignoring row
# veh_id 900021215901 arrived home without prior departure — ignoring row
# veh_id 900021237801 arrived home without prior departure — ignoring row
# veh_id 900021242101 arrived home without prior departure — ignoring row
# veh_id 900021282001 left home but never returned
# veh_id 900021296501 arrived home without prior departure — ignoring row
# veh_id 900021321901 left home but never returned
# veh_id 900021358501 arrived home without prior departure — ignoring row
# veh_id 900021367201 left home but never returned
# veh_id 900021410801 arrived home without prior departure — ignoring row
# veh_id 900021455401 arrived home without prior departure — ignoring row
# veh_id 900021469401 left home but never returned
# veh_id 900021478001 arrived home without prior departure — ignoring row
# veh_id 900021478001 arrived home without prior departure — ignoring row
# veh_id 900021483201 left home but never returned
# veh_id 900021488101 left home but never returned
# veh_id 900021489201 arrived home without prior departure — ignoring row
# veh_id 900021528001 arrived home without prior departure — ignoring row
# veh_id 900021530801 left home but never returned
# veh_id 900021537401 arrived home without prior departure — ignoring row
# veh_id 900021579201 arrived home without prior departure — ignoring row
# veh_id 900021581801 arrived home without prior departure — ignoring row
# veh_id 900021581801 arrived home without prior departure — ignoring row
# veh_id 900021608101 arrived home without prior departure — ignoring row
# veh_id 900021629601 arrived home without prior departure — ignoring row
# veh_id 900021641001 left home but never returned
# veh_id 900021669301 arrived home without prior departure — ignoring row
# veh_id 900021670101 left home but never returned
# veh_id 900021678201 arrived home without prior departure — ignoring row
# veh_id 900021678201 arrived home without prior departure — ignoring row
# veh_id 900021678401 left home but never returned
# veh_id 900021689201 arrived home without prior departure — ignoring row
# veh_id 900021691001 arrived home without prior departure — ignoring row
# veh_id 900021693901 arrived home without prior departure — ignoring row
# veh_id 900021712501 arrived home without prior departure — ignoring row
# veh_id 900021751101 left home but never returned
# veh_id 900021755101 arrived home without prior departure — ignoring row
# veh_id 900021755101 arrived home without prior departure — ignoring row
# veh_id 900021755101 arrived home without prior departure — ignoring row
# veh_id 900021755101 arrived home without prior departure — ignoring row
# veh_id 900021755101 arrived home without prior departure — ignoring row
# veh_id 900021755101 arrived home without prior departure — ignoring row
# veh_id 900021759801 arrived home without prior departure — ignoring row
# veh_id 900021787801 arrived home without prior departure — ignoring row
# veh_id 900021787801 arrived home without prior departure — ignoring row
# veh_id 900021790701 arrived home without prior departure — ignoring row
# Total trips found: 1464
# Weird Households: 116

# %%
household_ids = merged["HOUSEID"].to_list()

# %%
## Aggregating trips by household
house_id_results = {}
house_id_weird_households = []

# Iterate through each household ID
for household_id in household_ids:
    
    household_trips = trip2pub_filtered_used_car[trip2pub_filtered_used_car["HOUSEID"] == household_id] # Get all the trips for this household (which should have 1 car)
    household_trips = household_trips.sort_values(by=["TDAYDATE", "STRTTIME"])  # Sort by date and time of the trips
    household_trips["TRPHHVEH"].to_list()
    
    # Check that all trips are made in the household vehicle
    if not all(household_trips["TRPHHVEH"] == 1): # SHOULD NEVER GET TRIGGERED since we filtered trips to only include the car trips
        print(f"Household ID {household_id} has trips not made in household vehicle")
        continue
    
    if household_trips.empty:
        # This means the household made no trips (with their car at least) during this day
        travel_day = merged[merged["HOUSEID"] == household_id]["TRAVDAY_x"].values[0]
        house_id_results[household_id] = {
            "trips": [], # No trips were made
            "household_id": household_id,
            "day": travel_day,
        }
        continue
    
    # Otherwise, we need to find all the times the vehicle left the house and returned

    current_departure = None
    current_day = None
    
    trips = []
    travel_day = merged[merged["HOUSEID"] == household_id]["TRAVDAY_x"].values[0]

    for idx, row in household_trips.iterrows():
        whyfrom = row["WHYFROM"]
        whyto = row["WHYTO"]
        trip_start_time = row["STRTTIME"]
        trip_end_time = row["ENDTIME"]
        miles = row["VMT_MILE"]
        duration = row["TRVLCMIN"]
        day = row["TRAVDAY"]
        assert day == travel_day # should be the same day as the household travel day

        # Case 1: One-row round trip
        if whyfrom in [1, 2] and whyto in [1, 2]:
            trips.append((trip_start_time, trip_end_time, miles))
            current_departure = None  # Reset state in case something was set

        # Case 2: Leaving home (start of trip)
        elif whyfrom in [1, 2]:
            current_departure = trip_start_time

        # Case 3: Returning home (end of a trip)
        elif whyto in [1, 2] and current_departure is not None:
            trips.append((current_departure, trip_end_time, miles))
            current_departure = None

        # Case 4: Unexpected state (returning home without leaving)
        elif whyto in [1, 2] and current_departure is None:
            print(f"Household {household_id} arrived home without prior departure — ignoring row")
    
    if current_departure is not None:
        # This means they left home but never returned
        print(f"Household ID {household_id} left home but never returned")
        house_id_weird_households.append(household_id)
        continue
    # Add the trips to the results
    house_id_results[household_id] = {
        "trips": trips, # No trips were made
        "day": travel_day,
        }

print(f"Total trips found: {len(house_id_results)}")
print(f"Weird Households: {len(house_id_weird_households)}")
# Out:
# Household 9000013016 arrived home without prior departure — ignoring row
# Household 9000013045 arrived home without prior departure — ignoring row
# Household 9000013164 arrived home without prior departure — ignoring row
# Household 9000013164 arrived home without prior departure — ignoring row
# Household 9000013541 arrived home without prior departure — ignoring row
# Household ID 9000013541 left home but never returned
# Household 9000013707 arrived home without prior departure — ignoring row
# Household 9000013847 arrived home without prior departure — ignoring row
# Household ID 9000014086 left home but never returned
# Household 9000014155 arrived home without prior departure — ignoring row
# Household 9000014155 arrived home without prior departure — ignoring row
# Household 9000014454 arrived home without prior departure — ignoring row
# Household 9000014666 arrived home without prior departure — ignoring row
# Household 9000014666 arrived home without prior departure — ignoring row
# Household 9000014990 arrived home without prior departure — ignoring row
# Household 9000015289 arrived home without prior departure — ignoring row
# Household 9000015289 arrived home without prior departure — ignoring row
# Household 9000015575 arrived home without prior departure — ignoring row
# Household ID 9000015587 left home but never returned
# Household 9000016145 arrived home without prior departure — ignoring row
# Household 9000017260 arrived home without prior departure — ignoring row
# Household ID 9000017617 left home but never returned
# Household 9000017877 arrived home without prior departure — ignoring row
# Household 9000018415 arrived home without prior departure — ignoring row
# Household 9000018473 arrived home without prior departure — ignoring row
# Household 9000018684 arrived home without prior departure — ignoring row
# Household 9000019099 arrived home without prior departure — ignoring row
# Household 9000045505 arrived home without prior departure — ignoring row
# Household 9000045576 arrived home without prior departure — ignoring row
# Household 9000045708 arrived home without prior departure — ignoring row
# Household 9000046328 arrived home without prior departure — ignoring row
# Household 9000046569 arrived home without prior departure — ignoring row
# Household 9000046707 arrived home without prior departure — ignoring row
# Household 9000046707 arrived home without prior departure — ignoring row
# Household 9000046756 arrived home without prior departure — ignoring row
# Household ID 9000046848 left home but never returned
# Household 9000047021 arrived home without prior departure — ignoring row
# Household 9000047021 arrived home without prior departure — ignoring row
# Household 9000047093 arrived home without prior departure — ignoring row
# Household ID 9000047407 left home but never returned
# Household 9000047416 arrived home without prior departure — ignoring row
# Household 9000047416 arrived home without prior departure — ignoring row
# Household 9000047519 arrived home without prior departure — ignoring row
# Household 9000047528 arrived home without prior departure — ignoring row
# Household 9000047735 arrived home without prior departure — ignoring row
# Household ID 9000047971 left home but never returned
# Household 9000048035 arrived home without prior departure — ignoring row
# Household 9000048460 arrived home without prior departure — ignoring row
# Household ID 9000048521 left home but never returned
# Household 9000048628 arrived home without prior departure — ignoring row
# Household 9000048628 arrived home without prior departure — ignoring row
# Household 9000048724 arrived home without prior departure — ignoring row
# Household 9000048724 arrived home without prior departure — ignoring row
# Household 9000048929 arrived home without prior departure — ignoring row
# Household 9000048929 arrived home without prior departure — ignoring row
# Household 9000049042 arrived home without prior departure — ignoring row
# Household 9000049119 arrived home without prior departure — ignoring row
# Household 9000049188 arrived home without prior departure — ignoring row
# Household ID 9000049188 left home but never returned
# Household 9000049534 arrived home without prior departure — ignoring row
# Household 9000049594 arrived home without prior departure — ignoring row
# Household 9000049618 arrived home without prior departure — ignoring row
# Household ID 9000049797 left home but never returned
# Household 9000050201 arrived home without prior departure — ignoring row
# Household 9000050201 arrived home without prior departure — ignoring row
# Household 9000050201 arrived home without prior departure — ignoring row
# Household 9000050210 arrived home without prior departure — ignoring row
# Household 9000051318 arrived home without prior departure — ignoring row
# Household 9000051374 arrived home without prior departure — ignoring row
# Household 9000051458 arrived home without prior departure — ignoring row
# Household 9000051581 arrived home without prior departure — ignoring row
# Household 9000051674 arrived home without prior departure — ignoring row
# Household 9000052214 arrived home without prior departure — ignoring row
# Household ID 9000052282 left home but never returned
# Household 9000052411 arrived home without prior departure — ignoring row
# Household 9000052452 arrived home without prior departure — ignoring row
# Household ID 9000052452 left home but never returned
# Household 9000052652 arrived home without prior departure — ignoring row
# Household 9000052652 arrived home without prior departure — ignoring row
# Household 9000052652 arrived home without prior departure — ignoring row
# Household 9000052672 arrived home without prior departure — ignoring row
# Household 9000052815 arrived home without prior departure — ignoring row
# Household 9000052820 arrived home without prior departure — ignoring row
# Household 9000052902 arrived home without prior departure — ignoring row
# Household 9000052948 arrived home without prior departure — ignoring row
# Household ID 9000052948 left home but never returned
# Household ID 9000053904 left home but never returned
# Household 9000054151 arrived home without prior departure — ignoring row
# Household 9000054151 arrived home without prior departure — ignoring row
# Household 9000054198 arrived home without prior departure — ignoring row
# Household 9000054335 arrived home without prior departure — ignoring row
# Household 9000054676 arrived home without prior departure — ignoring row
# Household 9000054850 arrived home without prior departure — ignoring row
# Household 9000054902 arrived home without prior departure — ignoring row
# Household 9000055016 arrived home without prior departure — ignoring row
# Household 9000055043 arrived home without prior departure — ignoring row
# Household 9000055393 arrived home without prior departure — ignoring row
# Household 9000055409 arrived home without prior departure — ignoring row
# Household 9000055409 arrived home without prior departure — ignoring row
# Household 9000055409 arrived home without prior departure — ignoring row
# Household 9000055443 arrived home without prior departure — ignoring row
# Household 9000055641 arrived home without prior departure — ignoring row
# Household 9000055766 arrived home without prior departure — ignoring row
# Household 9000055986 arrived home without prior departure — ignoring row
# Household ID 9000056378 left home but never returned
# Household 9000056392 arrived home without prior departure — ignoring row
# Household 9000056416 arrived home without prior departure — ignoring row
# Household ID 9000056478 left home but never returned
# Household 9000056754 arrived home without prior departure — ignoring row
# Household 9000056754 arrived home without prior departure — ignoring row
# Household 9000056826 arrived home without prior departure — ignoring row
# Household ID 9000056838 left home but never returned
# Household 9000056962 arrived home without prior departure — ignoring row
# Household 9000057069 arrived home without prior departure — ignoring row
# Household ID 9000057074 left home but never returned
# Household 9000057119 arrived home without prior departure — ignoring row
# Household 9000057306 arrived home without prior departure — ignoring row
# Household 9000057454 arrived home without prior departure — ignoring row
# Household 9000057518 arrived home without prior departure — ignoring row
# Household 9000057677 arrived home without prior departure — ignoring row
# Household 9000057734 arrived home without prior departure — ignoring row
# Household 9000071826 arrived home without prior departure — ignoring row
# Household ID 9000071951 left home but never returned
# Household ID 9000072555 left home but never returned
# Household 9000072910 arrived home without prior departure — ignoring row
# Household 9000072910 arrived home without prior departure — ignoring row
# Household ID 9000073141 left home but never returned
# Household 9000073283 arrived home without prior departure — ignoring row
# Household 9000073341 arrived home without prior departure — ignoring row
# Household 9000073551 arrived home without prior departure — ignoring row
# Household 9000073551 arrived home without prior departure — ignoring row
# Household ID 9000073551 left home but never returned
# Household 9000073658 arrived home without prior departure — ignoring row
# Household 9000073705 arrived home without prior departure — ignoring row
# Household 9000073705 arrived home without prior departure — ignoring row
# Household 9000073705 arrived home without prior departure — ignoring row
# Household 9000073705 arrived home without prior departure — ignoring row
# Household 9000074144 arrived home without prior departure — ignoring row
# Household ID 9000074486 left home but never returned
# Household 9000074837 arrived home without prior departure — ignoring row
# Household 9000074983 arrived home without prior departure — ignoring row
# Household 9000075037 arrived home without prior departure — ignoring row
# Household 9000075111 arrived home without prior departure — ignoring row
# Household 9000075175 arrived home without prior departure — ignoring row
# Household 9000075214 arrived home without prior departure — ignoring row
# Household ID 9000075234 left home but never returned
# Household 9000075538 arrived home without prior departure — ignoring row
# Household 9000075788 arrived home without prior departure — ignoring row
# Household 9000076006 arrived home without prior departure — ignoring row
# Household ID 9000076006 left home but never returned
# Household 9000076075 arrived home without prior departure — ignoring row
# Household 9000076160 arrived home without prior departure — ignoring row
# Household 9000076160 arrived home without prior departure — ignoring row
# Household 9000076309 arrived home without prior departure — ignoring row
# Household 9000076309 arrived home without prior departure — ignoring row
# Household 9000076380 arrived home without prior departure — ignoring row
# Household ID 9000076440 left home but never returned
# Household 9000076464 arrived home without prior departure — ignoring row
# Household 9000076505 arrived home without prior departure — ignoring row
# Household 9000076723 arrived home without prior departure — ignoring row
# Household 9000076723 arrived home without prior departure — ignoring row
# Household 9000076724 arrived home without prior departure — ignoring row
# Household 9000076792 arrived home without prior departure — ignoring row
# Household 9000076801 arrived home without prior departure — ignoring row
# Household ID 9000076801 left home but never returned
# Household 9000076823 arrived home without prior departure — ignoring row
# Household 9000076895 arrived home without prior departure — ignoring row
# Household ID 9000077136 left home but never returned
# Household 9000077167 arrived home without prior departure — ignoring row
# Household ID 9000077256 left home but never returned
# Household 9000077404 arrived home without prior departure — ignoring row
# Household 9000077440 arrived home without prior departure — ignoring row
# Household 9000077685 arrived home without prior departure — ignoring row
# Household ID 9000086552 left home but never returned
# Household ID 9000086764 left home but never returned
# Household ID 9000086973 left home but never returned
# Household ID 9000087049 left home but never returned
# Household 9000087357 arrived home without prior departure — ignoring row
# Household 9000087475 arrived home without prior departure — ignoring row
# Household 9000087475 arrived home without prior departure — ignoring row
# Household 9000087475 arrived home without prior departure — ignoring row
# Household 9000087613 arrived home without prior departure — ignoring row
# Household 9000087681 arrived home without prior departure — ignoring row
# Household ID 9000087700 left home but never returned
# Household 9000087740 arrived home without prior departure — ignoring row
# Household 9000088023 arrived home without prior departure — ignoring row
# Household 9000088061 arrived home without prior departure — ignoring row
# Household 9000088075 arrived home without prior departure — ignoring row
# Household 9000088229 arrived home without prior departure — ignoring row
# Household 9000088313 arrived home without prior departure — ignoring row
# Household 9000088349 arrived home without prior departure — ignoring row
# Household 9000088349 arrived home without prior departure — ignoring row
# Household 9000088404 arrived home without prior departure — ignoring row
# Household 9000088716 arrived home without prior departure — ignoring row
# Household 9000088825 arrived home without prior departure — ignoring row
# Household 9000089173 arrived home without prior departure — ignoring row
# Household 9000089173 arrived home without prior departure — ignoring row
# Household 9000089173 arrived home without prior departure — ignoring row
# Household 9000089173 arrived home without prior departure — ignoring row
# Household ID 9000089369 left home but never returned
# Household 9000089676 arrived home without prior departure — ignoring row
# Household ID 9000089676 left home but never returned
# Household ID 9000089724 left home but never returned
# Household 9000089900 arrived home without prior departure — ignoring row
# Household 9000089920 arrived home without prior departure — ignoring row
# Household 9000089920 arrived home without prior departure — ignoring row
# Household 9000089920 arrived home without prior departure — ignoring row
# Household 9000095798 arrived home without prior departure — ignoring row
# Household 9000095839 arrived home without prior departure — ignoring row
# Household 9000095839 arrived home without prior departure — ignoring row
# Household 9000095910 arrived home without prior departure — ignoring row
# Household 9000096008 arrived home without prior departure — ignoring row
# Household 9000096009 arrived home without prior departure — ignoring row
# Household 9000096078 arrived home without prior departure — ignoring row
# Household ID 9000096097 left home but never returned
# Household ID 9000096175 left home but never returned
# Household ID 9000096190 left home but never returned
# Household 9000096270 arrived home without prior departure — ignoring row
# Household 9000096326 arrived home without prior departure — ignoring row
# Household ID 9000096451 left home but never returned
# Household 9000097215 arrived home without prior departure — ignoring row
# Household 9000097215 arrived home without prior departure — ignoring row
# Household ID 9000097249 left home but never returned
# Household ID 9000097251 left home but never returned
# Household ID 9000097259 left home but never returned
# Household 9000097954 arrived home without prior departure — ignoring row
# Household 9000097954 arrived home without prior departure — ignoring row
# Household ID 9000098416 left home but never returned
# Household 9000098513 arrived home without prior departure — ignoring row
# Household ID 9000098743 left home but never returned
# Household 9000098853 arrived home without prior departure — ignoring row
# Household 9000099020 arrived home without prior departure — ignoring row
# Household 9000104555 arrived home without prior departure — ignoring row
# Household 9000104660 arrived home without prior departure — ignoring row
# Household 9000104698 arrived home without prior departure — ignoring row
# Household 9000104897 arrived home without prior departure — ignoring row
# Household 9000104897 arrived home without prior departure — ignoring row
# Household ID 9000104993 left home but never returned
# Household 9000105442 arrived home without prior departure — ignoring row
# Household 9000105700 arrived home without prior departure — ignoring row
# Household 9000105700 arrived home without prior departure — ignoring row
# Household 9000105700 arrived home without prior departure — ignoring row
# Household 9000105700 arrived home without prior departure — ignoring row
# Household 9000105769 arrived home without prior departure — ignoring row
# Household 9000106111 arrived home without prior departure — ignoring row
# Household 9000106291 arrived home without prior departure — ignoring row
# Household 9000106418 arrived home without prior departure — ignoring row
# Household 9000106506 arrived home without prior departure — ignoring row
# Household 9000106528 arrived home without prior departure — ignoring row
# Household 9000106595 arrived home without prior departure — ignoring row
# Household 9000107513 arrived home without prior departure — ignoring row
# Household ID 9000107661 left home but never returned
# Household 9000107902 arrived home without prior departure — ignoring row
# Household ID 9000113631 left home but never returned
# Household 9000113654 arrived home without prior departure — ignoring row
# Household 9000113654 arrived home without prior departure — ignoring row
# Household 9000113692 arrived home without prior departure — ignoring row
# Household ID 9000113762 left home but never returned
# Household ID 9000113965 left home but never returned
# Household 9000114422 arrived home without prior departure — ignoring row
# Household ID 9000114580 left home but never returned
# Household 9000114685 arrived home without prior departure — ignoring row
# Household ID 9000114685 left home but never returned
# Household 9000114901 arrived home without prior departure — ignoring row
# Household 9000114946 arrived home without prior departure — ignoring row
# Household ID 9000114956 left home but never returned
# Household 9000114976 arrived home without prior departure — ignoring row
# Household 9000114976 arrived home without prior departure — ignoring row
# Household 9000114976 arrived home without prior departure — ignoring row
# Household 9000115191 arrived home without prior departure — ignoring row
# Household ID 9000115194 left home but never returned
# Household 9000115333 arrived home without prior departure — ignoring row
# Household 9000115413 arrived home without prior departure — ignoring row
# Household ID 9000115413 left home but never returned
# Household 9000115681 arrived home without prior departure — ignoring row
# Household 9000115721 arrived home without prior departure — ignoring row
# Household ID 9000115880 left home but never returned
# Household 9000116402 arrived home without prior departure — ignoring row
# Household 9000116780 arrived home without prior departure — ignoring row
# Household 9000116832 arrived home without prior departure — ignoring row
# Household 9000116832 arrived home without prior departure — ignoring row
# Household 9000117035 arrived home without prior departure — ignoring row
# Household ID 9000117074 left home but never returned
# Household 9000117159 arrived home without prior departure — ignoring row
# Household 9000117331 arrived home without prior departure — ignoring row
# Household 9000117340 arrived home without prior departure — ignoring row
# Household ID 9000117340 left home but never returned
# Household ID 9000117424 left home but never returned
# Household 9000124948 arrived home without prior departure — ignoring row
# Household 9000124984 arrived home without prior departure — ignoring row
# Household 9000124984 arrived home without prior departure — ignoring row
# Household 9000125257 arrived home without prior departure — ignoring row
# Household ID 9000125299 left home but never returned
# Household 9000125873 arrived home without prior departure — ignoring row
# Household 9000125873 arrived home without prior departure — ignoring row
# Household 9000125916 arrived home without prior departure — ignoring row
# Household 9000125916 arrived home without prior departure — ignoring row
# Household 9000125916 arrived home without prior departure — ignoring row
# Household 9000126144 arrived home without prior departure — ignoring row
# Household ID 9000126459 left home but never returned
# Household 9000126794 arrived home without prior departure — ignoring row
# Household 9000126910 arrived home without prior departure — ignoring row
# Household 9000127034 arrived home without prior departure — ignoring row
# Household 9000127208 arrived home without prior departure — ignoring row
# Household 9000127399 arrived home without prior departure — ignoring row
# Household 9000127399 arrived home without prior departure — ignoring row
# Household 9000127524 arrived home without prior departure — ignoring row
# Household 9000127677 arrived home without prior departure — ignoring row
# Household 9000127677 arrived home without prior departure — ignoring row
# Household ID 9000127677 left home but never returned
# Household 9000128123 arrived home without prior departure — ignoring row
# Household 9000128190 arrived home without prior departure — ignoring row
# Household 9000128190 arrived home without prior departure — ignoring row
# Household 9000128235 arrived home without prior departure — ignoring row
# Household 9000128235 arrived home without prior departure — ignoring row
# Household 9000128235 arrived home without prior departure — ignoring row
# Household 9000128367 arrived home without prior departure — ignoring row
# Household ID 9000128387 left home but never returned
# Household 9000128582 arrived home without prior departure — ignoring row
# Household ID 9000128582 left home but never returned
# Household 9000128610 arrived home without prior departure — ignoring row
# Household 9000128653 arrived home without prior departure — ignoring row
# Household 9000128808 arrived home without prior departure — ignoring row
# Household 9000128808 arrived home without prior departure — ignoring row
# Household ID 9000128994 left home but never returned
# Household ID 9000145133 left home but never returned
# Household 9000145258 arrived home without prior departure — ignoring row
# Household 9000145258 arrived home without prior departure — ignoring row
# Household 9000145304 arrived home without prior departure — ignoring row
# Household ID 9000145350 left home but never returned
# Household 9000145354 arrived home without prior departure — ignoring row
# Household 9000145373 arrived home without prior departure — ignoring row
# Household ID 9000145373 left home but never returned
# Household 9000145683 arrived home without prior departure — ignoring row
# Household ID 9000146465 left home but never returned
# Household 9000146466 arrived home without prior departure — ignoring row
# Household 9000146466 arrived home without prior departure — ignoring row
# Household 9000146466 arrived home without prior departure — ignoring row
# Household 9000146574 arrived home without prior departure — ignoring row
# Household 9000146675 arrived home without prior departure — ignoring row
# Household 9000146708 arrived home without prior departure — ignoring row
# Household 9000147480 arrived home without prior departure — ignoring row
# Household 9000147559 arrived home without prior departure — ignoring row
# Household 9000147598 arrived home without prior departure — ignoring row
# Household 9000147598 arrived home without prior departure — ignoring row
# Household ID 9000147745 left home but never returned
# Household 9000147866 arrived home without prior departure — ignoring row
# Household 9000147886 arrived home without prior departure — ignoring row
# Household ID 9000148127 left home but never returned
# Household 9000148360 arrived home without prior departure — ignoring row
# Household 9000148533 arrived home without prior departure — ignoring row
# Household 9000148867 arrived home without prior departure — ignoring row
# Household 9000148871 arrived home without prior departure — ignoring row
# Household 9000149047 arrived home without prior departure — ignoring row
# Household 9000149272 arrived home without prior departure — ignoring row
# Household ID 9000149281 left home but never returned
# Household ID 9000149396 left home but never returned
# Household ID 9000162143 left home but never returned
# Household 9000162239 arrived home without prior departure — ignoring row
# Household 9000162287 arrived home without prior departure — ignoring row
# Household ID 9000162355 left home but never returned
# Household 9000162496 arrived home without prior departure — ignoring row
# Household ID 9000162496 left home but never returned
# Household 9000162942 arrived home without prior departure — ignoring row
# Household 9000162961 arrived home without prior departure — ignoring row
# Household ID 9000163256 left home but never returned
# Household ID 9000163372 left home but never returned
# Household 9000164022 arrived home without prior departure — ignoring row
# Household 9000164166 arrived home without prior departure — ignoring row
# Household ID 9000164166 left home but never returned
# Household ID 9000164234 left home but never returned
# Household 9000164378 arrived home without prior departure — ignoring row
# Household 9000164632 arrived home without prior departure — ignoring row
# Household 9000164674 arrived home without prior departure — ignoring row
# Household 9000164908 arrived home without prior departure — ignoring row
# Household 9000165005 arrived home without prior departure — ignoring row
# Household ID 9000165005 left home but never returned
# Household 9000165049 arrived home without prior departure — ignoring row
# Household 9000165134 arrived home without prior departure — ignoring row
# Household 9000165287 arrived home without prior departure — ignoring row
# Household 9000165356 arrived home without prior departure — ignoring row
# Household 9000165356 arrived home without prior departure — ignoring row
# Household 9000165356 arrived home without prior departure — ignoring row
# Household ID 9000166037 left home but never returned
# Household 9000166310 arrived home without prior departure — ignoring row
# Household 9000166354 arrived home without prior departure — ignoring row
# Household 9000166524 arrived home without prior departure — ignoring row
# Household 9000166636 arrived home without prior departure — ignoring row
# Household ID 9000166636 left home but never returned
# Household 9000166757 arrived home without prior departure — ignoring row
# Household 9000166997 arrived home without prior departure — ignoring row
# Household 9000167442 arrived home without prior departure — ignoring row
# Household 9000167464 arrived home without prior departure — ignoring row
# Household ID 9000167464 left home but never returned
# Household 9000167480 arrived home without prior departure — ignoring row
# Household 9000167597 arrived home without prior departure — ignoring row
# Household 9000167601 arrived home without prior departure — ignoring row
# Household 9000167627 arrived home without prior departure — ignoring row
# Household 9000167632 arrived home without prior departure — ignoring row
# Household 9000168043 arrived home without prior departure — ignoring row
# Household 9000168204 arrived home without prior departure — ignoring row
# Household 9000168204 arrived home without prior departure — ignoring row
# Household 9000168263 arrived home without prior departure — ignoring row
# Household ID 9000168263 left home but never returned
# Household 9000168620 arrived home without prior departure — ignoring row
# Household ID 9000168662 left home but never returned
# Household 9000168830 arrived home without prior departure — ignoring row
# Household 9000168830 arrived home without prior departure — ignoring row
# Household 9000169052 arrived home without prior departure — ignoring row
# Household 9000169507 arrived home without prior departure — ignoring row
# Household 9000169507 arrived home without prior departure — ignoring row
# Household 9000169708 arrived home without prior departure — ignoring row
# Household 9000170081 arrived home without prior departure — ignoring row
# Household 9000170107 arrived home without prior departure — ignoring row
# Household 9000170408 arrived home without prior departure — ignoring row
# Household ID 9000170408 left home but never returned
# Household 9000170559 arrived home without prior departure — ignoring row
# Household 9000170559 arrived home without prior departure — ignoring row
# Household ID 9000170614 left home but never returned
# Household 9000170629 arrived home without prior departure — ignoring row
# Household 9000170747 arrived home without prior departure — ignoring row
# Household 9000170747 arrived home without prior departure — ignoring row
# Household ID 9000171285 left home but never returned
# Household 9000171537 arrived home without prior departure — ignoring row
# Household 9000171549 arrived home without prior departure — ignoring row
# Household 9000171560 arrived home without prior departure — ignoring row
# Household 9000171854 arrived home without prior departure — ignoring row
# Household 9000172092 arrived home without prior departure — ignoring row
# Household ID 9000172355 left home but never returned
# Household 9000172408 arrived home without prior departure — ignoring row
# Household 9000172438 arrived home without prior departure — ignoring row
# Household 9000172460 arrived home without prior departure — ignoring row
# Household 9000172508 arrived home without prior departure — ignoring row
# Household ID 9000172736 left home but never returned
# Household 9000172820 arrived home without prior departure — ignoring row
# Household 9000172820 arrived home without prior departure — ignoring row
# Household 9000172845 arrived home without prior departure — ignoring row
# Household 9000172852 arrived home without prior departure — ignoring row
# Household 9000172875 arrived home without prior departure — ignoring row
# Household ID 9000172875 left home but never returned
# Household 9000173020 arrived home without prior departure — ignoring row
# Household 9000173435 arrived home without prior departure — ignoring row
# Household 9000173453 arrived home without prior departure — ignoring row
# Household 9000173491 arrived home without prior departure — ignoring row
# Household 9000173491 arrived home without prior departure — ignoring row
# Household 9000173760 arrived home without prior departure — ignoring row
# Household 9000174065 arrived home without prior departure — ignoring row
# Household 9000174471 arrived home without prior departure — ignoring row
# Household 9000174658 arrived home without prior departure — ignoring row
# Household 9000174783 arrived home without prior departure — ignoring row
# Household 9000174936 arrived home without prior departure — ignoring row
# Household ID 9000174984 left home but never returned
# Household ID 9000174999 left home but never returned
# Household 9000175190 arrived home without prior departure — ignoring row
# Household 9000175190 arrived home without prior departure — ignoring row
# Household 9000175190 arrived home without prior departure — ignoring row
# Household 9000175220 arrived home without prior departure — ignoring row
# Household 9000175250 arrived home without prior departure — ignoring row
# Household 9000175259 arrived home without prior departure — ignoring row
# Household ID 9000175265 left home but never returned
# Household 9000175507 arrived home without prior departure — ignoring row
# Household 9000175598 arrived home without prior departure — ignoring row
# Household 9000175676 arrived home without prior departure — ignoring row
# Household ID 9000175734 left home but never returned
# Household 9000208651 arrived home without prior departure — ignoring row
# Household 9000209086 arrived home without prior departure — ignoring row
# Household 9000209086 arrived home without prior departure — ignoring row
# Household 9000209086 arrived home without prior departure — ignoring row
# Household 9000209248 arrived home without prior departure — ignoring row
# Household 9000209310 arrived home without prior departure — ignoring row
# Household 9000209542 arrived home without prior departure — ignoring row
# Household 9000210068 arrived home without prior departure — ignoring row
# Household 9000210068 arrived home without prior departure — ignoring row
# Household 9000210068 arrived home without prior departure — ignoring row
# Household 9000210068 arrived home without prior departure — ignoring row
# Household 9000210088 arrived home without prior departure — ignoring row
# Household 9000210088 arrived home without prior departure — ignoring row
# Household 9000210088 arrived home without prior departure — ignoring row
# Household 9000210088 arrived home without prior departure — ignoring row
# Household 9000210088 arrived home without prior departure — ignoring row
# Household 9000210088 arrived home without prior departure — ignoring row
# Household ID 9000210197 left home but never returned
# Household ID 9000210252 left home but never returned
# Household 9000210264 arrived home without prior departure — ignoring row
# Household ID 9000210421 left home but never returned
# Household ID 9000210452 left home but never returned
# Household 9000210576 arrived home without prior departure — ignoring row
# Household ID 9000210618 left home but never returned
# Household 9000210691 arrived home without prior departure — ignoring row
# Household ID 9000210707 left home but never returned
# Household 9000210742 arrived home without prior departure — ignoring row
# Household 9000210952 arrived home without prior departure — ignoring row
# Household 9000210996 arrived home without prior departure — ignoring row
# Household 9000211084 arrived home without prior departure — ignoring row
# Household ID 9000211171 left home but never returned
# Household 9000211429 arrived home without prior departure — ignoring row
# Household 9000211432 arrived home without prior departure — ignoring row
# Household 9000211498 arrived home without prior departure — ignoring row
# Household 9000211604 arrived home without prior departure — ignoring row
# Household 9000211604 arrived home without prior departure — ignoring row
# Household ID 9000211604 left home but never returned
# Household 9000211861 arrived home without prior departure — ignoring row
# Household 9000211925 arrived home without prior departure — ignoring row
# Household 9000212044 arrived home without prior departure — ignoring row
# Household 9000212150 arrived home without prior departure — ignoring row
# Household 9000212159 arrived home without prior departure — ignoring row
# Household 9000212378 arrived home without prior departure — ignoring row
# Household 9000212421 arrived home without prior departure — ignoring row
# Household ID 9000212820 left home but never returned
# Household 9000212965 arrived home without prior departure — ignoring row
# Household ID 9000213219 left home but never returned
# Household 9000213585 arrived home without prior departure — ignoring row
# Household ID 9000213672 left home but never returned
# Household 9000214108 arrived home without prior departure — ignoring row
# Household 9000214554 arrived home without prior departure — ignoring row
# Household ID 9000214694 left home but never returned
# Household 9000214780 arrived home without prior departure — ignoring row
# Household 9000214780 arrived home without prior departure — ignoring row
# Household ID 9000214832 left home but never returned
# Household ID 9000214881 left home but never returned
# Household 9000214892 arrived home without prior departure — ignoring row
# Household 9000215280 arrived home without prior departure — ignoring row
# Household ID 9000215308 left home but never returned
# Household 9000215374 arrived home without prior departure — ignoring row
# Household 9000215792 arrived home without prior departure — ignoring row
# Household 9000215818 arrived home without prior departure — ignoring row
# Household 9000215818 arrived home without prior departure — ignoring row
# Household 9000216081 arrived home without prior departure — ignoring row
# Household 9000216296 arrived home without prior departure — ignoring row
# Household ID 9000216410 left home but never returned
# Household 9000216693 arrived home without prior departure — ignoring row
# Household ID 9000216701 left home but never returned
# Household 9000216782 arrived home without prior departure — ignoring row
# Household 9000216782 arrived home without prior departure — ignoring row
# Household ID 9000216784 left home but never returned
# Household 9000216892 arrived home without prior departure — ignoring row
# Household 9000216910 arrived home without prior departure — ignoring row
# Household 9000216939 arrived home without prior departure — ignoring row
# Household 9000217125 arrived home without prior departure — ignoring row
# Household ID 9000217511 left home but never returned
# Household 9000217551 arrived home without prior departure — ignoring row
# Household 9000217551 arrived home without prior departure — ignoring row
# Household 9000217551 arrived home without prior departure — ignoring row
# Household 9000217551 arrived home without prior departure — ignoring row
# Household 9000217551 arrived home without prior departure — ignoring row
# Household 9000217551 arrived home without prior departure — ignoring row
# Household 9000217598 arrived home without prior departure — ignoring row
# Household 9000217878 arrived home without prior departure — ignoring row
# Household 9000217878 arrived home without prior departure — ignoring row
# Household 9000217907 arrived home without prior departure — ignoring row
# Total trips found: 2378
# Weird Households: 116

# %%
trip2pub_filtered_used_car[trip2pub_filtered_used_car["HOUSEID"] == 9000045478][['WHYFROM', 'WHYTO', 'WHYTRP1S', 'VMT_MILE', 'TRVLCMIN', 'TRPTRANS', 'TRPHHVEH', 'TRIPID', 'TDAYDATE','TRAVDAY', 'STRTTIME', 'ENDTIME']]
# Out:
#       WHYFROM  WHYTO  WHYTRP1S   VMT_MILE  TRVLCMIN  TRPTRANS  TRPHHVEH
# 2219        1      1         1  13.622747        30         1         1  \
# 2220        1      1         1  13.737725        30         1         1
#
#       TRIPID  TDAYDATE  TRAVDAY  STRTTIME  ENDTIME
# 2219       1    202203        6      1030     1100
# 2220       2    202203        6      1400     1430

# %%
results[9000072555]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[166], line 1
# ----> 1 results[9000072555]
#
# KeyError: 9000072555

# %%
round_trips = pd.DataFrame(results)

# %%
round_trips[round_trips["day"] = 1]
# Out:
#       household_id  day  departure_time  arrival_time      miles  duration
# 0       9000013145  7.0          1316.0        1610.0  17.310752      30.0
# 1       9000013246  5.0           750.0        1545.0   0.746426       5.0
# 2       9000013246  5.0          1555.0        1730.0   9.254817      10.0
# 3       9000013313  6.0          1325.0        1430.0   1.535736      15.0
# 4       9000013613  2.0          1707.0        2202.0  35.970789      47.0
# ...            ...  ...             ...           ...        ...       ...
# 1033    9000217878  6.0           720.0         735.0   2.863891       7.0
# 1034    9000217878  6.0          1510.0        1613.0   6.315103      13.0
# 1035    9000217943  2.0           900.0        1400.0   4.920447      30.0
# 1036    9000218013  5.0          1300.0        1500.0   3.059043      15.0
# 1037    9000218040  5.0          1230.0        1242.0   0.257303       2.0
#
# [1038 rows x 6 columns]

# %%
obs_days_per_household = trip2pub_filtered.groupby("HOUSEID")["TDAYDATE"].nunique()
obs_days_per_household.value_counts()
# Out:
# TDAYDATE
# 1    939
# Name: count, dtype: int64

# %%
print(f"Num Trips Leaving Home: {len(trips_leaving_home)}")
print(f"Num Trips Arriving Home: {len(trips_arriving_home)}")
# Out:
# Num Trips Leaving Home: 1482
# Num Trips Arriving Home: 1401

# %%
trips_leaving_home[trips_leaving_home["WHYTO"].isin([1, 2])]
# Out:
#           HOUSEID  PERSONID  TRIPID  SEQ_TRIPID     VEHCASEID  FRSTHM  PARK
# 2219   9000045478         1       1           1  900004547801       1     2  \
# 2220   9000045478         1       2           2  900004547801       1     2
# 3297   9000047971         2       1           1  900004797101       2     2
# 3691   9000048791         1       1           1            -1       1     2
# 3692   9000048791         1       2           2            -1       1     2
# 5942   9000054238         1       3           3            -1       1     2
# 6749   9000056478         1       1           1  900005647801       2     2
# 6873   9000056754         1       1           1  900005675401       2     2
# 6892   9000056835         1       1           1  900005683501       1     2
# 8254   9000073528         1       1           1  900007352801       1     2
# 9526   9000075929         1       1           1  900007592901       1     2
# 9899   9000076611         1       1           1            -1       1     2
# 11634  9000088763         1       1           1  900008876301       1     2
# 11635  9000088763         1       2           2  900008876301       1     2
# 12645  9000096613         1       1           1            -1       1     2
# 12646  9000096613         1       2           2            -1       1     2
# 12797  9000097121         1       1           1  900009712101       1     2
# 13540  9000098471         1       1           1  900009847101       1     2
# 15478  9000113791         1       1           1  900011379101       1     2
# 16729  9000116585         1       1           1  900011658501       1     2
# 16730  9000116585         2       1           1  900011658501       1    -1
# 17329  9000117923         1       1           1  900011792301       1     2
# 17796  9000125916         2       1           1            -1       1    -1
# 17797  9000125916         2       2           2  900012591601       1    -1
# 19711  9000145784         1       1           1  900014578401       2     2
# 21039  9000148814         1       1           1  900014881401       1     2
# 22277  9000164301         1       1           1  900016430101       1     2
# 22278  9000164301         1       2           2  900016430101       1     2
# 25113  9000170581         2       1           1            -1       2    -1
# 25966  9000172491         1       1           1  900017249101       2     2
# 26840  9000174667         1       1           1  900017466701       1     2
# 26841  9000174667         1       2           2  900017466701       1     2
# 26875  9000174755         2       5           5  900017475501       1    -1
# 26876  9000174755         2       6           6  900017475501       1    -1
# 27513  9000208956         1       7           7  900020895601       1     2
# 28231  9000210691         2       1           1  900021069101       1     2
# 28232  9000210691         2       2           2  900021069101       1     2
# 28542  9000211498         1       1           1  900021149801       2     2
#
#        HHMEMDRV  TDWKND  TRAVDAY  ...  WORKER  DRIVER  R_RACE  R_HISP  PROXY
# 2219          1       2        6  ...       2       1       2       2      1  \
# 2220          1       2        6  ...       2       1       2       2      1
# 3297          1       2        4  ...       1       1       1       2      1
# 3691         -1       2        4  ...       2       1       1       2      1
# 3692         -1       2        4  ...       2       1       1       2      1
# 5942         -1       2        5  ...       1       1       1       2      1
# 6749          1       2        5  ...       1       1       1       2      1
# 6873          1       1        1  ...       1       1       3       2      1
# 6892          1       2        5  ...       1       1       1       2      1
# 8254          1       1        6  ...       2       1       2       2      1
# 9526          1       1        7  ...       1       1       1       2      1
# 9899         -1       2        2  ...       2       1       1       2      1
# 11634         1       2        6  ...       2       1       1       2      1
# 11635         1       1        6  ...       2       1       1       2      1
# 12645        -1       1        7  ...       1       2       1       2      1
# 12646        -1       1        7  ...       1       2       1       2      1
# 12797         1       1        7  ...       1       1       1       2      1
# 13540         1       2        2  ...       2       1      97       1      1
# 15478         1       2        6  ...       2       1       1       2      1
# 16729         1       1        1  ...       2       1       1       2      1
# 16730         1       1        1  ...       2       1       1       2      2
# 17329         1       1        1  ...       2       1       1       2      1
# 17796         1       1        1  ...      -1      -1       1       1      2
# 17797         1       1        1  ...      -1      -1       1       1      2
# 19711         1       2        4  ...       1       1      97       1      1
# 21039         1       2        5  ...       2       1       1       2      1
# 22277         1       2        2  ...       2       1       1       2      1
# 22278         1       2        2  ...       2       1       1       2      1
# 25113        -1       2        3  ...       1       2       2       1      1
# 25966         1       2        2  ...       1       1       1       2      1
# 26840         1       2        4  ...       2       1       1       2      1
# 26841         1       2        4  ...       2       1       1       2      1
# 26875         1       1        7  ...       2       1       1       2      2
# 26876         1       1        7  ...       2       1       1       2      2
# 27513         1       2        4  ...       2       1       1       2      1
# 28231         1       2        5  ...       1       1       1       2      1
# 28232         1       2        5  ...       1       1       1       2      1
# 28542         2       2        2  ...       1       1       2       2      1
#
#        EDUC  PRMACT  R_SEX_IMP  VEHTYPE  HHFAMINC_IMP
# 2219      6      97          2        1             7
# 2220      6      97          2        1             7
# 3297      3      -1          2        1             6
# 3691      7       5          1       -1             3
# 3692      7       5          1       -1             3
# 5942      6      -1          1       -1             6
# 6749      3      -1          1        1             5
# 6873      6      -1          2        1             8
# 6892      7      -1          2        3            11
# 8254      6       5          2        1             3
# 9526      6      -1          1        4             8
# 9899      5       5          2       -1             6
# 11634     2       3          2        1             5
# 11635     2       3          2        1             5
# 12645     6      -1          1       -1             4
# 12646     6      -1          1       -1             4
# 12797     7      -1          1        1             8
# 13540     3       2          1        1             1
# 15478     8       5          1        3             6
# 16729     6       5          1        3             8
# 16730     5       5          2        3             8
# 17329     3       5          1        2             7
# 17796    -1      -1          1       -1             8
# 17797    -1      -1          1        3             8
# 19711     4      -1          1        1             6
# 21039     5       5          2        1             4
# 22277     5       5          2        1             3
# 22278     5       5          2        1             3
# 25113     2      -1          1       -1             7
# 25966     5      -1          2        3             6
# 26840     6       5          1        3             6
# 26841     6       5          1        3             6
# 26875     4       4          2        2             4
# 26876     4       4          2        2             4
# 27513     7       5          2        1             5
# 28231     6      -1          2        3             7
# 28232     6      -1          2        3             7
# 28542     4      -1          2        3             4
#
# [38 rows x 85 columns]
